# %% [markdown]
# <a href="https://colab.research.google.com/github/maidacundo/DeepLearningREPO/blob/main/Soluzione-Esame-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
import random
from cv2 import GaussianBlur
import numpy as np

import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Input, Dense, MaxPooling2D, Add, Dropout, ConvLSTM2D, GaussianNoise, BatchNormalization , Activation, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def getDataset():
  (x_train, _), (x_test, _) = tf.keras.datasets.cifar10.load_data()
  normalize = lambda x: x/x.max()
  x_train = normalize(x_train)
  x_test = normalize(x_test)
  createBlurred = lambda arr: np.array([GaussianBlur(x, (5,5), ((random.random()*3)+1)) + (0.02*np.random.normal(0,1, (32, 32, 3))) for x in arr])
  return (createBlurred(x_train), x_train), (createBlurred(x_test), x_test)

# %%
(x_train_blured, x_train), (x_test_blured, x_test) = getDataset()
print(f"Train size: {x_train_blured.shape}. Test size: {x_test_blured.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step
# Train size: (50000, 32, 32, 3). Test size: (10000, 32, 32, 3)

# %%
def res_block(x, filter, kernel_size):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, kernel_size, padding = 'same')(x)
    # x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, kernel_size, padding = 'same')(x)
    # x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def dense_block(x, filters, kernel_size, layers):
  layers_connections = []
  layers_connections.append(x)
  for i in range(layers):
    cat = sum(layers_connections)
    x = res_block(cat, filters,kernel_size)
    layers_connections.append(x)
  x = tf.keras.layers.Add()([x, cat])
  return x

# %%
# modello

# input
input_shape = (32, 32, 3)
inputs = Input(shape=input_shape)

ngf = 64
mult = 1

# upsampling

x = Conv2D(ngf*mult, (2, 2), strides = 1, padding = 'same') (inputs)
x = res_block(x, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))
conv_1 = res_block(x, ngf*mult,(2, 2))

mult = mult/2

x = Conv2D(ngf*mult, (2, 2), strides = 1, padding = 'same') (conv_1)
x = res_block(x, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))

conv_2 = MaxPooling2D((2, 2), strides = 2, padding='same') (x)

mult = mult/2

x = Conv2D(ngf*mult, (2, 2), strides = 1, padding = 'same') (conv_2)
x = res_block(x, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))
conv_3 = res_block(x, ngf*mult,(2, 2))

# hidden layer
x = Conv2D(ngf*mult, (3, 3), strides = 1, padding = 'same') (x)
x = Conv2D(ngf*mult, (3, 3), strides = 1, padding = 'same') (x)
x = Conv2D(ngf*mult, (3, 3), strides = 1, padding = 'same') (x)

# deconvolution

cat_0 = x + conv_3

x = res_block(cat_0, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))

mult = mult*2

x = Conv2DTranspose(ngf*mult, (2, 2), strides = 1, padding = 'same') (x)

cat_1 = UpSampling2D((2,2)) (x + conv_2)

x = res_block(cat_1, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))

mult = mult*2

x = Conv2DTranspose(ngf*mult, (3, 3), strides = 1, padding = 'same') (x)

# transpose here
cat_2 = x + conv_1

x = res_block(cat_2, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))
x = res_block(x, ngf*mult,(2, 2))

# max pooling

x = Conv2DTranspose(32, (2, 2), strides = 1, padding = 'same') (x)
x = Conv2DTranspose(16, (2, 2), strides = 1, padding = 'same') (x)

outputs = Conv2DTranspose(3, (1, 1), strides = 1, activation = 'sigmoid', padding = 'same') (x)

# %%
model = Model(inputs=inputs,outputs=outputs)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_211 (Conv2D)            (None, 32, 32, 64)   832         ['input_7[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 32, 32, 64)   16448       ['conv2d_211[0][0]']
#
#  activation_186 (Activation)    (None, 32, 32, 64)   0           ['conv2d_212[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_186[0][0]']
#
#  add_87 (Add)                   (None, 32, 32, 64)   0           ['conv2d_213[0][0]',
#                                                                   'conv2d_211[0][0]']
#
#  activation_187 (Activation)    (None, 32, 32, 64)   0           ['add_87[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_187[0][0]']
#
#  activation_188 (Activation)    (None, 32, 32, 64)   0           ['conv2d_214[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_188[0][0]']
#
#  add_88 (Add)                   (None, 32, 32, 64)   0           ['conv2d_215[0][0]',
#                                                                   'activation_187[0][0]']
#
#  activation_189 (Activation)    (None, 32, 32, 64)   0           ['add_88[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_189[0][0]']
#
#  activation_190 (Activation)    (None, 32, 32, 64)   0           ['conv2d_216[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_190[0][0]']
#
#  add_89 (Add)                   (None, 32, 32, 64)   0           ['conv2d_217[0][0]',
#                                                                   'activation_189[0][0]']
#
#  activation_191 (Activation)    (None, 32, 32, 64)   0           ['add_89[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 32, 32, 32)   8224        ['activation_191[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 32, 32, 32)   4128        ['conv2d_218[0][0]']
#
#  activation_192 (Activation)    (None, 32, 32, 32)   0           ['conv2d_219[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_192[0][0]']
#
#  add_90 (Add)                   (None, 32, 32, 32)   0           ['conv2d_220[0][0]',
#                                                                   'conv2d_218[0][0]']
#
#  activation_193 (Activation)    (None, 32, 32, 32)   0           ['add_90[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_193[0][0]']
#
#  activation_194 (Activation)    (None, 32, 32, 32)   0           ['conv2d_221[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_194[0][0]']
#
#  add_91 (Add)                   (None, 32, 32, 32)   0           ['conv2d_222[0][0]',
#                                                                   'activation_193[0][0]']
#
#  activation_195 (Activation)    (None, 32, 32, 32)   0           ['add_91[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_195[0][0]']
#
#  activation_196 (Activation)    (None, 32, 32, 32)   0           ['conv2d_223[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_196[0][0]']
#
#  add_92 (Add)                   (None, 32, 32, 32)   0           ['conv2d_224[0][0]',
#                                                                   'activation_195[0][0]']
#
#  activation_197 (Activation)    (None, 32, 32, 32)   0           ['add_92[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_197[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 16, 16, 16)   2064        ['max_pooling2d_4[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 16, 16, 16)   1040        ['conv2d_225[0][0]']
#
#  activation_198 (Activation)    (None, 16, 16, 16)   0           ['conv2d_226[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_198[0][0]']
#
#  add_93 (Add)                   (None, 16, 16, 16)   0           ['conv2d_227[0][0]',
#                                                                   'conv2d_225[0][0]']
#
#  activation_199 (Activation)    (None, 16, 16, 16)   0           ['add_93[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_199[0][0]']
#
#  activation_200 (Activation)    (None, 16, 16, 16)   0           ['conv2d_228[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_200[0][0]']
#
#  add_94 (Add)                   (None, 16, 16, 16)   0           ['conv2d_229[0][0]',
#                                                                   'activation_199[0][0]']
#
#  activation_201 (Activation)    (None, 16, 16, 16)   0           ['add_94[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_201[0][0]']
#
#  activation_202 (Activation)    (None, 16, 16, 16)   0           ['conv2d_230[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 16, 16, 16)   2320        ['activation_201[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_202[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 16, 16, 16)   2320        ['conv2d_232[0][0]']
#
#  add_95 (Add)                   (None, 16, 16, 16)   0           ['conv2d_231[0][0]',
#                                                                   'activation_201[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 16, 16, 16)   2320        ['conv2d_233[0][0]']
#
#  activation_203 (Activation)    (None, 16, 16, 16)   0           ['add_95[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 16, 16, 16)  0           ['conv2d_234[0][0]',
#  ambda)                                                           'activation_203[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 16, 16, 16)   1040        ['tf.__operators__.add_18[0][0]']
#
#  activation_204 (Activation)    (None, 16, 16, 16)   0           ['conv2d_235[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_204[0][0]']
#
#  add_96 (Add)                   (None, 16, 16, 16)   0           ['conv2d_236[0][0]',
#                                                                   'tf.__operators__.add_18[0][0]']
#
#  activation_205 (Activation)    (None, 16, 16, 16)   0           ['add_96[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_205[0][0]']
#
#  activation_206 (Activation)    (None, 16, 16, 16)   0           ['conv2d_237[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_206[0][0]']
#
#  add_97 (Add)                   (None, 16, 16, 16)   0           ['conv2d_238[0][0]',
#                                                                   'activation_205[0][0]']
#
#  activation_207 (Activation)    (None, 16, 16, 16)   0           ['add_97[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_207[0][0]']
#
#  activation_208 (Activation)    (None, 16, 16, 16)   0           ['conv2d_239[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 16, 16, 16)   1040        ['activation_208[0][0]']
#
#  add_98 (Add)                   (None, 16, 16, 16)   0           ['conv2d_240[0][0]',
#                                                                   'activation_207[0][0]']
#
#  activation_209 (Activation)    (None, 16, 16, 16)   0           ['add_98[0][0]']
#
#  conv2d_transpose_27 (Conv2DTra  (None, 16, 16, 32)  2080        ['activation_209[0][0]']
#  nspose)
#
#  tf.__operators__.add_19 (TFOpL  (None, 16, 16, 32)  0           ['conv2d_transpose_27[0][0]',
#  ambda)                                                           'max_pooling2d_4[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 32)  0           ['tf.__operators__.add_19[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 32, 32, 32)   4128        ['up_sampling2d_4[0][0]']
#
#  activation_210 (Activation)    (None, 32, 32, 32)   0           ['conv2d_241[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_210[0][0]']
#
#  add_99 (Add)                   (None, 32, 32, 32)   0           ['conv2d_242[0][0]',
#                                                                   'up_sampling2d_4[0][0]']
#
#  activation_211 (Activation)    (None, 32, 32, 32)   0           ['add_99[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_211[0][0]']
#
#  activation_212 (Activation)    (None, 32, 32, 32)   0           ['conv2d_243[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_212[0][0]']
#
#  add_100 (Add)                  (None, 32, 32, 32)   0           ['conv2d_244[0][0]',
#                                                                   'activation_211[0][0]']
#
#  activation_213 (Activation)    (None, 32, 32, 32)   0           ['add_100[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_213[0][0]']
#
#  activation_214 (Activation)    (None, 32, 32, 32)   0           ['conv2d_245[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_214[0][0]']
#
#  add_101 (Add)                  (None, 32, 32, 32)   0           ['conv2d_246[0][0]',
#                                                                   'activation_213[0][0]']
#
#  activation_215 (Activation)    (None, 32, 32, 32)   0           ['add_101[0][0]']
#
#  conv2d_transpose_28 (Conv2DTra  (None, 32, 32, 64)  18496       ['activation_215[0][0]']
#  nspose)
#
#  tf.__operators__.add_20 (TFOpL  (None, 32, 32, 64)  0           ['conv2d_transpose_28[0][0]',
#  ambda)                                                           'activation_191[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 32, 32, 64)   16448       ['tf.__operators__.add_20[0][0]']
#
#  activation_216 (Activation)    (None, 32, 32, 64)   0           ['conv2d_247[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_216[0][0]']
#
#  add_102 (Add)                  (None, 32, 32, 64)   0           ['conv2d_248[0][0]',
#                                                                   'tf.__operators__.add_20[0][0]']
#
#  activation_217 (Activation)    (None, 32, 32, 64)   0           ['add_102[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_217[0][0]']
#
#  activation_218 (Activation)    (None, 32, 32, 64)   0           ['conv2d_249[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_218[0][0]']
#
#  add_103 (Add)                  (None, 32, 32, 64)   0           ['conv2d_250[0][0]',
#                                                                   'activation_217[0][0]']
#
#  activation_219 (Activation)    (None, 32, 32, 64)   0           ['add_103[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_219[0][0]']
#
#  activation_220 (Activation)    (None, 32, 32, 64)   0           ['conv2d_251[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 32, 32, 64)   16448       ['activation_220[0][0]']
#
#  add_104 (Add)                  (None, 32, 32, 64)   0           ['conv2d_252[0][0]',
#                                                                   'activation_219[0][0]']
#
#  activation_221 (Activation)    (None, 32, 32, 64)   0           ['add_104[0][0]']
#
#  conv2d_transpose_29 (Conv2DTra  (None, 32, 32, 32)  8224        ['activation_221[0][0]']
#  nspose)
#
#  conv2d_transpose_30 (Conv2DTra  (None, 32, 32, 16)  2064        ['conv2d_transpose_29[0][0]']
#  nspose)
#
#  conv2d_transpose_31 (Conv2DTra  (None, 32, 32, 3)   51          ['conv2d_transpose_30[0][0]']
#  nspose)
#
# ==================================================================================================
# Total params: 308,387
# Trainable params: 308,387
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam',metrics=['acc'])

hist = model.fit(x_train_blured.reshape(-1, 32, 32, 3), 
          x_train.reshape(-1, 32, 32, 3), 
          epochs=20, 
          batch_size=200,
          validation_data=(x_test_blured, x_test))
# Out:
# Epoch 1/20
# 142/250 [================>.............] - ETA: 17s - loss: 0.0096 - acc: 0.7139
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-5907b7e62791> in <module>()
#       5           epochs=20,
#       6           batch_size=200,
# ----> 7           validation_data=(x_test_blured, x_test))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
def plot_history(model_history,keys):
    m,val_m = keys
    plt.plot(model_history.history[m])
    plt.plot(model_history.history[val_m])
    plt.ylabel(m)
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

plot_history(hist,['loss','val_loss'])

# %%
from tensorflow.keras.losses import MeanSquaredError

y_true = x_test
y_pred = model.predict(x_test_blured)

mse = MeanSquaredError()
mse(y_true, y_pred).numpy()

#0.0023

#0.0041738243220982366
#0.004219622105503972
#0.00404854369862134
#0.003909846398674108
#0.00379532259022029
#0.003393252
#0.0026358136

# %%
#utility function to pick samples to be tested

def get_samples(arr, n):
    temp = random.sample(range(len(arr)), n)
    result = arr[temp]
    return result, temp

num = 3
figsize = 15
org, temp = get_samples(x_test, num)
blur = x_test_blured[temp]
preds = model.predict(blur.reshape(-1, 32, 32, 3))
#plotting results
plt.figure(figsize = (figsize, figsize))
print('Original Images')
for i in range(num):
    plt.subplot(1, num, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(org[i])
plt.show()
plt.figure(figsize = (figsize, figsize))
print('Blurred Images')
for i in range(num):
    plt.subplot(1, num, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(blur[i])
plt.show()
plt.figure(figsize = (figsize, figsize))
print('Predicted Images')
for i in range(num):
    plt.subplot(1, num, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(preds[i])
plt.show()

# %%
from keras.layers import Input
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D
from keras.layers.core import Dense, Flatten
from keras.layers import BatchNormalization
from keras.models import Model


from keras.layers import Input, Activation, Add
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.core import Lambda
from keras.models import Model

ndf = 64
ngf = 64
n_blocks_gen = 9
output_nc = 3
input_shape_discriminator = (32, 32, output_nc)

inputs = Input(shape=(32, 32, 3))

x = Conv2D(filters=ngf, kernel_size=(2,2), padding='valid')(inputs)
# x = BatchNormalization()(x)
x = Activation('relu')(x)
print(x)
# Increase filter number
n_downsampling = 2
for i in range(n_downsampling):
    mult = 2**i
    x = Conv2D(filters=ngf*mult*2, kernel_size=(3,3), strides=2, padding='same')(x)
    print(x)
    # x = BatchNormalization()(x)
    x = Activation('relu')(x)

# Apply 9 ResNet blocks
mult = 2**n_downsampling
for i in range(n_blocks_gen):
    x = res_block(x, ngf*mult, (2, 2))

# Decrease filter number to 3 (RGB)
for i in range(n_downsampling):
    mult = 2**(n_downsampling - i)
    x = Conv2DTranspose(filters=int(ngf * mult / 2), kernel_size=(2, 2), strides=2-i, padding='same')(x)
    # x = BatchNormalization()(x)
    x = Activation('relu')(x)

x = Conv2DTranspose(filters=32, kernel_size=(2, 2), strides=2, padding='same')(x)

x = Conv2D(filters=32, kernel_size=(3,3), padding='same')(x)
x = Conv2D(filters=64, kernel_size=(2,2), padding='same')(x)
x = Conv2D(filters=output_nc, kernel_size=(1,1), padding='same')(x)

x = Activation('tanh')(x)

# Add direct connection from input to output and recenter to [-1, 1]
# outputs = Add()([x, inputs])
# outputs = Lambda(lambda z: z/2)(x)
# print(outputs)
x = Conv2D(8, (2, 2), strides = 1, padding = 'same') (x)
#decode
x = Conv2DTranspose(16, (2, 2), strides = 1, padding = 'same') (x)
x = Conv2DTranspose(32, (2, 2), strides = 1, padding = 'same') (x)
x = Conv2DTranspose(64, (2, 2), strides = 1, padding = 'same') (x)
outputs = Conv2DTranspose(3, (1, 1), strides = 1, activation = 'sigmoid', padding = 'same') (x)
model = Model(inputs=inputs, outputs=outputs, name='Generator')
model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 31, 31, 64), dtype=tf.float32, name=None), name='activation_24/Relu:0', description="created by layer 'activation_24'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 128), dtype=tf.float32, name=None), name='conv2d_25/BiasAdd:0', description="created by layer 'conv2d_25'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 256), dtype=tf.float32, name=None), name='conv2d_26/BiasAdd:0', description="created by layer 'conv2d_26'")
# Model: "Generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_24 (Conv2D)             (None, 31, 31, 64)   832         ['input_2[0][0]']
#
#  activation_24 (Activation)     (None, 31, 31, 64)   0           ['conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 128)  73856       ['activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 128)  0           ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 256)    295168      ['activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 8, 8, 256)    0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 8, 8, 256)    0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_27[0][0]']
#
#  add_9 (Add)                    (None, 8, 8, 256)    0           ['conv2d_28[0][0]',
#                                                                   'activation_26[0][0]']
#
#  activation_28 (Activation)     (None, 8, 8, 256)    0           ['add_9[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_28[0][0]']
#
#  activation_29 (Activation)     (None, 8, 8, 256)    0           ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_29[0][0]']
#
#  add_10 (Add)                   (None, 8, 8, 256)    0           ['conv2d_30[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 8, 8, 256)    0           ['add_10[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 8, 8, 256)    0           ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_31[0][0]']
#
#  add_11 (Add)                   (None, 8, 8, 256)    0           ['conv2d_32[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 8, 8, 256)    0           ['add_11[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_32[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 256)    0           ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_33[0][0]']
#
#  add_12 (Add)                   (None, 8, 8, 256)    0           ['conv2d_34[0][0]',
#                                                                   'activation_32[0][0]']
#
#  activation_34 (Activation)     (None, 8, 8, 256)    0           ['add_12[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_34[0][0]']
#
#  activation_35 (Activation)     (None, 8, 8, 256)    0           ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_35[0][0]']
#
#  add_13 (Add)                   (None, 8, 8, 256)    0           ['conv2d_36[0][0]',
#                                                                   'activation_34[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 256)    0           ['add_13[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 8, 8, 256)    0           ['conv2d_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_37[0][0]']
#
#  add_14 (Add)                   (None, 8, 8, 256)    0           ['conv2d_38[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 256)    0           ['add_14[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_38[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 256)    0           ['conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_39[0][0]']
#
#  add_15 (Add)                   (None, 8, 8, 256)    0           ['conv2d_40[0][0]',
#                                                                   'activation_38[0][0]']
#
#  activation_40 (Activation)     (None, 8, 8, 256)    0           ['add_15[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_40[0][0]']
#
#  activation_41 (Activation)     (None, 8, 8, 256)    0           ['conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_41[0][0]']
#
#  add_16 (Add)                   (None, 8, 8, 256)    0           ['conv2d_42[0][0]',
#                                                                   'activation_40[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 256)    0           ['add_16[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_42[0][0]']
#
#  activation_43 (Activation)     (None, 8, 8, 256)    0           ['conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 256)    262400      ['activation_43[0][0]']
#
#  add_17 (Add)                   (None, 8, 8, 256)    0           ['conv2d_44[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_44 (Activation)     (None, 8, 8, 256)    0           ['add_17[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 16, 16, 128)  131200     ['activation_44[0][0]']
#  spose)
#
#  activation_45 (Activation)     (None, 16, 16, 128)  0           ['conv2d_transpose_3[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 16, 16, 64)  32832       ['activation_45[0][0]']
#  spose)
#
#  activation_46 (Activation)     (None, 16, 16, 64)   0           ['conv2d_transpose_4[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 32)  8224        ['activation_46[0][0]']
#  spose)
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 32)   9248        ['conv2d_transpose_5[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 64)   8256        ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 3)    195         ['conv2d_46[0][0]']
#
#  activation_47 (Activation)     (None, 32, 32, 3)    0           ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 8)    104         ['activation_47[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 32, 32, 16)  528         ['conv2d_48[0][0]']
#  spose)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 32, 32, 32)  2080        ['conv2d_transpose_6[0][0]']
#  spose)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 32, 32, 64)  8256        ['conv2d_transpose_7[0][0]']
#  spose)
#
#  conv2d_transpose_9 (Conv2DTran  (None, 32, 32, 3)   195         ['conv2d_transpose_8[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 5,294,174
# Trainable params: 5,294,174
# Non-trainable params: 0
# __________________________________________________________________________________________________
